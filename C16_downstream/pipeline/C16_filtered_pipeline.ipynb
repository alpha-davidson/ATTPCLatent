# %%
import random
import numpy as np
import tqdm
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import os.path
import pandas as pd
from sklearn import preprocessing
import os

# %% [markdown]
# # User inputs

# %%
sample_size = 512 #enter the size to which events will be up/downsampled

# designed for data in the following format:
# x[0] ,y[1] ,z[2] ,Amplitude[3], id[4]
TRACK_CLASS = False
dimension = 4 # desired dimension of data to be input
ISOTOPE = 'C16'

# %%
data = np.load('../data/' + ISOTOPE + '_size256_final_f.npy', allow_pickle=True)
event_lens = np.load('../data/' + ISOTOPE + '_size256_events_included.npy', allow_pickle=True)

print(len(data))
print(len(event_lens))
#assert data.shape == (event_lens.size, np.max(event_lens), 5), 'Array has incorrect shape'
#assert len(np.unique(data[:,:,4])) == event_lens.size, 'Array has incorrect Event_ids'
# Out:
# 2059
# 2059
