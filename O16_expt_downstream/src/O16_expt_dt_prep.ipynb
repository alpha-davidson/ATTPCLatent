# %% [markdown]
# # Prepare Data for DW Task
#
# This notebook is dedicated to the tasks of preparing the dataset for the downstream task of O16 experimental and a PointNet model pre-trained on ModelNet10 dataset.

# %%
import os
import numpy as np
import datetime

# %%
# Load initial O16_size512 dataset
O16_expt_data_pointnet = np.load('O16_expt_downstream/voxel_data/O16_size512_shuffled_voxels.npy', allow_pickle=True)
O16_expt_labels_pointnet = O16_expt_data_pointnet[:, 0, 4]
O16_expt_data_pointnet = O16_expt_data_pointnet[:, :, :3]
print(O16_expt_data_pointnet.shape) # (1814, 512, 3)
print(O16_expt_labels_pointnet.shape)
print(O16_expt_labels_pointnet[900:1000]) #
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Load initial O16_size512 dataset
# ----> 2 O16_expt_data_pointnet = np.load('O16_expt_downstream/voxel_data/O16_size512_shuffled_voxels.npy', allow_pickle=True)
#       3 O16_expt_labels_pointnet = O16_expt_data_pointnet[:, 0, 4]
#       4 O16_expt_data_pointnet = O16_expt_data_pointnet[:, :, :3]
#
# File ~/.conda/envs/tpcnet/lib/python3.11/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'O16_expt_downstream/voxel_data/O16_size512_shuffled_voxels.npy'

# %%
# Save datasets for OG Pointnet model
np.save('TPCNet/O16_expt_downstream/ready/tpcnet_O16_expt_data_512.npy', O16_expt_data_pointnet)
np.save('TPCNet/O16_expt_downstream/ready/tpcnet_O16_expt_labels_512.npy', O16_expt_labels_pointnet)

print(O16_expt_labels_pointnet.shape)
# Out:
# (2814,)
