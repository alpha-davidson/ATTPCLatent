# %%
import os
import numpy as np
import datetime

# %%
# Load initial Mg22_size512 dataset
Mg22_expt_data_pointnet = np.load('voxel_data/Mg22_size512_shuffled_voxels.npy', allow_pickle=True)
Mg22_expt_labels_pointnet = Mg22_expt_data_pointnet[:, 0, 4]
Mg22_expt_data_pointnet = Mg22_expt_data_pointnet[:, :, :3]
print(Mg22_expt_data_pointnet.shape) # (1814, 512, 3)
print(Mg22_expt_labels_pointnet.shape)
print(Mg22_expt_labels_pointnet[900:1000]) #
# Out:
# (5958, 512, 3)
# (5958,)
# [3. 3. 3. 3. 2. 2. 2. 3. 2. 2. 2. 3. 2. 2. 3. 2. 2. 2. 3. 3. 2. 2. 3. 3.
#  3. 2. 3. 2. 2. 2. 3. 3. 3. 3. 3. 2. 3. 1. 2. 3. 3. 2. 2. 2. 3. 3. 2. 3.
#  2. 3. 2. 3. 3. 3. 3. 2. 2. 3. 3. 3. 3. 2. 3. 3. 3. 3. 3. 3. 3. 3. 2. 2.
#  3. 3. 2. 2. 3. 3. 2. 3. 2. 2. 2. 2. 3. 2. 2. 2. 1. 3. 3. 2. 2. 3. 2. 2.
#  3. 3. 3. 2.]

# %%
# Save datasets for OG Pointnet model
os.makedirs('ready')
np.save('ready/tpcnet_Mg22_expt_data_512.npy', Mg22_expt_data_pointnet)
np.save('ready/tpcnet_Mg22_expt_labels_512.npy', Mg22_expt_labels_pointnet)

print(Mg22_expt_labels_pointnet.shape)
# Out:
# (5958,)
