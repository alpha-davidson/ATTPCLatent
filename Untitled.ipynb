# %%
import random
import h5py
import numpy as np
import tqdm
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from sklearn.preprocessing import StandardScaler
import math
import sys

data_base_voxels = np.load('voxel_data/Mg22_size512_base_voxels.npy')
data_shuffled_voxels_only = np.load('voxel_data/Mg22_size512_shuffled_voxels_only.npy')
data_even_tracks = np.load('voxel_data/Mg22_size512_even_tracks_sampled.npy')
data_normalized = np.load('voxel_data/Mg22_size512_sampled_normal.npy')
data_voxelated = np.load('voxel_data/Mg22_size512_voxelated.npy')

# %%
print(data_base_voxels.shape)
print(data_base_voxels[0])

for i in range(10):
#print(data[i,:,0:3].shape)
#print(data2[i,:,0:3].shape)
    plt.plot(data_base_voxels[i,:,0],data_base_voxels[i,:,1],'.')
    plt.plot(data_voxelated[i,:,0],data_voxelated[i,:,1],'.')
    plt.xlim(0,1)
    plt.ylim(0,1)
    plt.show()
# Out:
# (2428, 512, 6)
# [[ 0.15704265  0.20549516  0.0991195  13.          3.          0.        ]
#  [ 0.14741867  0.21118438  0.10213836 13.          0.          0.        ]
#  [ 0.14260667  0.21382978  0.10515723 13.          0.          0.        ]
#  ...
#  [ 0.26771858  0.29712448  0.02238994 19.          0.          0.        ]
#  [ 0.19553866  0.17215668  0.1672956  22.          0.          0.        ]
#  [ 0.06080275  0.24452287  0.27849057  4.          0.          0.        ]]

# %%
for i in range(10):
#print(data[i,:,0:3].shape)
#print(data2[i,:,0:3].shape)
    plt.plot(data2[i,:,0],data[i,:,1],'.')
    plt.show()

# %%
i = 0
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(data_voxelated[i,:,0], data_voxelated[i,:,2], data_voxelated[i,:,1],s=0.1)
ax.axes.set_xlim3d(0,1)
ax.axes.set_zlim3d(0,1)
ax.axes.set_ylim3d(0,1)
fig.show()

i = 0
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(data_shuffled_voxels_only[i,:,0], data_shuffled_voxels_only[i,:,2], data_shuffled_voxels_only[i,:,1],s=0.1)
ax.axes.set_xlim3d(0,1)
ax.axes.set_zlim3d(0,1)
ax.axes.set_ylim3d(0,1)
fig.show()

for i in range(10):
    fig = plt.figure()
    ax = plt.axes(projection='3d')
    ax.scatter3D(data_voxelated[i,:,0], data_voxelated[i,:,2], data_voxelated[i,:,1],s=0.1,c="green")
    ax.scatter3D(data_shuffled_voxels_only[i,:,0], data_shuffled_voxels_only[i,:,2], data_shuffled_voxels_only[i,:,1],s=0.1,c="blue")
    ax.axes.set_xlim3d(0,1)
    ax.axes.set_zlim3d(0,1)
    ax.axes.set_ylim3d(0,1)
    fig.show()
